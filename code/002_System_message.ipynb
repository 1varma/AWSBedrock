# %%
import boto3

client = boto3.client('bedrock-runtime', region_name='us-east-2')

model_id = 'us.anthropic.claude-haiku-4-5-20251001-v1:0'

# %%
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": [
            {"text": text}
        ]
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant", 
        "content": [
            {"text": text}
        ]
    }
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {"modelId": model_id, "messages": messages}
    
    if system:
        params["system"] = [{"text": system}]
    
    response = client.converse(**params)
    
    return response["output"]["message"]["content"][0]["text"]

# %%
messages = []

text = input()

add_user_message(messages, text)

system_prompt = input("Sytem Prompt: ")

response = chat(messages, system_prompt)

add_assistant_message(messages, response)

print(response)
# Out:
# # DuckDB Installation on AWS EC2
#
# I'll help you install DuckDB on EC2. Here are the steps:
#
# ## 1. **Connect to Your EC2 Instance**
# ```bash
# ssh -i your-key.pem ec2-user@your-instance-ip
# # or for Ubuntu
# ssh -i your-key.pem ubuntu@your-instance-ip
# ```
#
# ## 2. **Update System Packages**
#
# **For Amazon Linux 2/RHEL:**
# ```bash
# sudo yum update -y
# ```
#
# **For Ubuntu:**
# ```bash
# sudo apt update && sudo apt upgrade -y
# ```
#
# ## 3. **Install DuckDB**
#
# ### Option A: Using Package Manager (Recommended)
#
# **For Amazon Linux 2:**
# ```bash
# sudo yum install -y duckdb
# ```
#
# **For Ubuntu:**
# ```bash
# sudo apt install -y duckdb
# ```
#
# ### Option B: Using Python pip
# ```bash
# # Install Python and pip first
# sudo yum install -y python3 python3-pip  # Amazon Linux
# # or
# sudo apt install -y python3 python3-pip  # Ubuntu
#
# # Install DuckDB Python package
# pip3 install duckdb
# ```
#
# ### Option C: Download Binary
# ```bash
# # Download latest release
# wget https://github.com/duckdb/duckdb/releases/download/v1.0.0/duckdb_cli-linux-amd64.zip
#
# # Unzip and move to PATH
# unzip duckdb_cli-linux-amd64.zip
# sudo mv duckdb /usr/local/bin/
# chmod +x /usr/local/bin/duckdb
# ```
#
# ## 4. **Verify Installation**
# ```bash
# duckdb --version
# # or for Python
# python3 -c "import duckdb; print(duckdb.__version__)"
# ```
#
# ## 5. **Quick Test**
# ```bash
# duckdb
# # Then run: SELECT 42;
# ```
#
# ---
#
# ## Common Issues & Fixes
#
# | Issue | Solution |
# |-------|----------|
# | Command not found | Add `/usr/local/bin` to PATH or use full path |
# | Permission denied | Run `chmod +x /path/to/duckdb` |
# | Missing dependencies | Install build tools: `sudo yum groupinstall "Development Tools"` |
#
# **Which OS is your EC2 running?** I can provide more specific guidance!
