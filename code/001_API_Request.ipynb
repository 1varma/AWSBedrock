# %%
import boto3, json

# %%
client = boto3.client('bedrock-runtime', region_name='us-east-2')

# %%
model_id = 'us.anthropic.claude-haiku-4-5-20251001-v1:0'

user_message = {
    'role' : 'user',
    'content' : [
        {'text':'10001-10000=?'}
    ]
}

# %%
response = client.converse(
    modelId=model_id,
    messages=[user_message]
)

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '6e055bc5-344f-4edc-b225-125d19f1edca',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Tue, 13 Jan 2026 22:53:51 GMT',
#    'content-type': 'application/json',
#    'content-length': '333',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '6e055bc5-344f-4edc-b225-125d19f1edca'},
#   'RetryAttempts': 0},
#  'output': {'message': {'role': 'assistant',
#    'content': [{'text': '10001 - 10000 = **1**'}]}},
#  'stopReason': 'end_turn',
#  'usage': {'inputTokens': 15,
#   'outputTokens': 16,
#   'totalTokens': 31,
#   'cacheReadInputTokens': 0,
#   'cacheWriteInputTokens': 0},
#  'metrics': {'latencyMs': 701}}

# %%
response['output']['message']['content'][0]['text']
# Out:
# '10001 - 10000 = **1**'

# %%
response['output']['message']
# Out:
# {'role': 'assistant', 'content': [{'text': '10001 - 10000 = **1**'}]}
